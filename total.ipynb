# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %%
total_az_v = np.array([0.58157405, 0.66465606, 0.74773806, 0.83082007, 0.91390208,
       0.99698408, 1.08006609, 1.1631481 , 1.24623011, 1.32931211, 1.41239412, 1.49547613,
       1.57855813, 1.66164014])

total_heating = np.array([9.20664657,  5.70221779, 57.08261   , 12.23641426,  5.18136435,
       26.03036411, 50.72673366, 46.449570151818605, 18.34868842122633, 11.57079981,  7.5187465 , 13.45143889,
        5.58121633, 13.54766137])

heating1 = np.array([19.93697048, 12.69960579, 10.24328885, 15.42602162, 14.87496945,
       19.5135117 , 17.08332242])
az1 = np.array([1.6 , 1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 ])

heating2=np.array([24.06473222, 37.67170591, 74.96086915, 97.47068734])
az2 = np.array([1.95, 2.  , 2.05, 2.1])

az3 = np.array([2.15, 2.2 , 2.25, 2.3,2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 , 2.75, 2.8 , 2.85,
       2.9 , 3. , 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 4. ])
heating3 = np.array([134.25494386, 134.41573867, 117.67547248,  97.68316909, 56.39798, 100.37511,  42.0585 ,  49.64873,  26.05422,  24.03255,
        27.96864,  30.48593,  34.09569,  56.35457,  45.     ,  44.90466, 40.6244592 , 31.14684895, 60.68962067, 38.90083172, 75.33200443,
       53.89678501, 75.10202465, 60.40554118, 64.18726459, 56.58149571,
       74.07174973])

heating4 = np.array([ 1.25653902,  1.56329214,  2.40571111,  5.64475894,  5.09970629,
        4.70546514,  9.7881302 , 11.3178459 ,  4.37433346])

az4 = np.array([0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55, 0.6 , 0.65])

az_41 = np.array([0.65, 0.70, 0.75, 0.8, 0.95, 1.00, 1.05, 1.10, 1.15, 1.20])
heating_41 = np.array([ 5.63191989,  9.64482495, 19.86894793, 13.11693763, 24.60898884,
       22.2947498 , 38.41711538, 43.24333736, 29.6164708 , 19.57109264])

# %%
# f = interp1d(total_az_v, total_heating, kind='linear')
# x_new = np.linspace(total_az_v[0], total_az_v[-1], 1000)

# %%
az_v_30 = np.concatenate([total_az_v, az1, az4, az2])
heating_30 = np.concatenate([total_heating, heating1, heating4, heating2])

# %%
plt.figure(figsize=(20,10))
plt.plot(az_v_30, heating_30, 'o', label='Az=194 el=53')

#plt.plot(az3, heating3, 'o', label='Heating after 5 minutes')
plt.plot(az_41, heating_41, 'o', label='Az=194 el=41')
#plt.plot(x_new, f(x_new))
plt.title('Heating vs Az speed (250mK bottom)')
plt.ylabel('$\Delta$T [mK] after 30 minute scan')
plt.xlabel('Az speed (d/s)')
#plt.yscale('log')
plt.legend()
plt.grid()

# %%
import sys
sys.path.insert(0, '../slowdaq')
from load_slowdaq import load_slow
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
slowdir1 = '/data/pb2/ChileData/slowdaq/22300000/20210305/'
slowdir2 = '/data/pb2/ChileData/slowdaq/22300000/20210306/'

# %%
files1 = sorted(glob(slowdir1+'*808*'))
files2 = sorted(glob(slowdir2+'*808*'))
files = np.concatenate((files1, files2))
files
# Out:
# array(['/data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_205230_Run22300808_000.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_205235_Run22300808_001.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_205703_Run22300808_002.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_212702_Run22300808_003.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_215938_Run22300808_004.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_222937_Run22300808_005.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_230233_Run22300808_006.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_233238_Run22300808_007.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_000418_Run22300808_008.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_003422_Run22300808_009.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_010531_Run22300808_010.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_013530_Run22300808_011.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_020615_Run22300808_012.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_023619_Run22300808_013.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_030743_Run22300808_014.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_033746_Run22300808_015.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_040829_Run22300808_016.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_043832_Run22300808_017.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_050910_Run22300808_019.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_053919_Run22300808_020.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_060951_Run22300808_021.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_063954_Run22300808_022.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_071032_Run22300808_023.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_074035_Run22300808_024.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_081113_Run22300808_025.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_084120_Run22300808_026.log.gz',
#        '/data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_091203_Run22300808_027.log.gz'],
#       dtype='<U92')

# %%
data = load_slow(files = files, slowdir=slowdir, sources=['Lakeshore151'])
# Out:
# Loading /data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_205230_Run22300808_000.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_205235_Run22300808_001.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_205703_Run22300808_002.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_212702_Run22300808_003.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_215938_Run22300808_004.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_222937_Run22300808_005.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_230233_Run22300808_006.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210305/slowdaq_20210305_233238_Run22300808_007.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_000418_Run22300808_008.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_003422_Run22300808_009.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_010531_Run22300808_010.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_013530_Run22300808_011.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_020615_Run22300808_012.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_023619_Run22300808_013.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_030743_Run22300808_014.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_033746_Run22300808_015.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_040829_Run22300808_016.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_043832_Run22300808_017.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_050910_Run22300808_019.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_053919_Run22300808_020.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_060951_Run22300808_021.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_063954_Run22300808_022.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_071032_Run22300808_023.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_074035_Run22300808_024.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_081113_Run22300808_025.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_084120_Run22300808_026.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210306/slowdaq_20210306_091203_Run22300808_027.log.gz
# Existing sources: Lakeshore151
# Loaging slowdata done. It took 45.647732 seconds

# %%
ls = data['Lakeshore151']
time = np.array(ls['time']) - ls['time'][0]
key = 'MODEL370_370A4A_T'
#l = len(ls[key][0])
tmp = np.array(ls[key])[:,12]

# %%
plt.plot(time, tmp)

# %%
#fig = plt.figure(figsize=(20,10))

# for i in range(l):
#     tmp = np.array(ls[key])[:,i]

#     plt.plot(time, tmp, label=i)
s = 0
e = 10000
plt.plot(time[s:e], tmp[s:e])
#plt.plot(x, tmp_interp)
#plt.plot(x[rise], tmp_interp[rise], 'x')

# %%
time = time[s:e]
tmp = tmp[s:e]

x = np.linspace(time[0], time[-1], 150)
tmp_interp = np.interp(x, time, tmp)

# %%
rise = np.where(np.diff(tmp_interp)>1e-3)[0]
rise
# Out:
# array([  0,  31,  32,  43,  44,  45,  55,  56,  57,  58,  67,  68,  78,
#         79,  80,  81,  82,  90,  91,  92, 102, 103, 105, 114, 115, 125,
#        126, 127, 137, 138, 139])

# %%
a = np.where(np.diff(rise)<10)[0]+1
a
# Out:
# array([ 2,  4,  5,  7,  8,  9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 21, 22,
#        23, 24, 26, 27, 29, 30])

# %%
start_indices = np.delete(rise, a)
start_indices
# Out:
# array([  0,  31,  43,  55,  78, 102, 125, 137])

# %%
conv = len(tmp_interp)/(x[-1] - x[0])
end_indices = np.ceil(start_indices + 30*60*conv).astype(dtype=np.int)
end_indices
# Out:
# array([  6,  37,  49,  61,  84, 108, 131, 143])

# %%
end_indices = np.array([  5,  18,  31,  45,  58,  71,  84,  97, 111, 124, 137])

# %%
plt.figure(figsize=(20,10))
plt.plot(time, tmp)
plt.plot(x, tmp_interp)
plt.plot(x[rise], tmp_interp[rise], 'x')
plt.plot(x[start_indices], tmp_interp[start_indices], 'o')
plt.plot(x[end_indices], tmp_interp[end_indices], 'o')

# %%
heating = tmp_interp[end_indices]-tmp_interp[start_indices] 
heating *= 1000
heating
# Out:
# array([40.6244592 , 31.14684895, 60.68962067, 38.90083172, 75.33200443,
#        53.89678501, 75.10202465, 60.40554118, 64.18726459, 56.58149571,
#        74.07174973])

# %%
az_v = np.array([0.65, 0.70, 0.75, 0.8, 0.95, 1.00, 1.05, 1.10, 1.15, 1.20])
# Out:
# array([3. , 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 4. ])

# %%
plt.figure(figsize=(20,10))
plt.plot(az_v, heating, 'o', label='Az center = 194, El = 53')
plt.title('Heating vs Az speed (250mK bottom)')
plt.ylabel('$\Delta$T after 5 minutes [mK]')
plt.xlabel('Az speed (d/s)')
plt.legend()
plt.grid()

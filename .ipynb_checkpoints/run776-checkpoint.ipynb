# %%
import sys
sys.path.insert(0, '../slowdaq')
from load_slowdaq import load_slow
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
slowdir = '/data/pb2/ChileData/slowdaq/22300000/20210227/'

# %%
files = sorted(glob(slowdir+'*776*'))
files
# Out:
# ['/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_063554_Run22300776_000.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_063559_Run22300776_001.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_063640_Run22300776_002.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_070641_Run22300776_003.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_071235_Run22300776_004.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_075735_Run22300776_005.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_080328_Run22300776_006.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_084833_Run22300776_007.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_085422_Run22300776_008.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_093927_Run22300776_009.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_094515_Run22300776_010.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_103020_Run22300776_011.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_103608_Run22300776_012.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_112113_Run22300776_013.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_112707_Run22300776_014.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_121206_Run22300776_015.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_121800_Run22300776_016.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_130300_Run22300776_017.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_130853_Run22300776_018.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_135359_Run22300776_019.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_135952_Run22300776_020.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_144453_Run22300776_021.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_145046_Run22300776_022.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_153552_Run22300776_023.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_154146_Run22300776_024.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_162651_Run22300776_025.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_163245_Run22300776_026.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_171751_Run22300776_027.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_172344_Run22300776_028.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_180850_Run22300776_029.log.gz']

# %%
data = load_slow(files = files, slowdir=slowdir, sources=['Lakeshore151'])
# Out:
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_063554_Run22300776_000.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_063559_Run22300776_001.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_063640_Run22300776_002.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_070641_Run22300776_003.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_071235_Run22300776_004.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_075735_Run22300776_005.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_080328_Run22300776_006.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_084833_Run22300776_007.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_085422_Run22300776_008.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_093927_Run22300776_009.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_094515_Run22300776_010.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_103020_Run22300776_011.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_103608_Run22300776_012.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_112113_Run22300776_013.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_112707_Run22300776_014.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_121206_Run22300776_015.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_121800_Run22300776_016.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_130300_Run22300776_017.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_130853_Run22300776_018.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_135359_Run22300776_019.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_135952_Run22300776_020.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_144453_Run22300776_021.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_145046_Run22300776_022.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_153552_Run22300776_023.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_154146_Run22300776_024.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_162651_Run22300776_025.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_163245_Run22300776_026.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_171751_Run22300776_027.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_172344_Run22300776_028.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210227/slowdaq_20210227_180850_Run22300776_029.log.gz
# Existing sources: Lakeshore151
# Loaging slowdata done. It took 38.653344 seconds

# %%
ls = data['Lakeshore151']
time = np.array(ls['time']) - ls['time'][0]
key = 'MODEL370_370A4A_T'
#l = len(ls[key][0])
tmp = np.array(ls[key])[:,12]

# %%
plt.plot(time, tmp)

# %%
#fig = plt.figure(figsize=(20,10))

# for i in range(l):
#     tmp = np.array(ls[key])[:,i]

#     plt.plot(time, tmp, label=i)
s = 300
e = 7800
plt.plot(time[s:e], tmp[s:e])
#plt.plot(x, tmp_interp)
#plt.plot(x[rise], tmp_interp[rise], 'x')

# %%
time = time[s:e]
tmp = tmp[s:e]

x = np.linspace(time[0], time[-1], 150)
tmp_interp = np.interp(x, time, tmp)

# %%
rise = np.where(np.diff(tmp_interp)>1e-3)[0]
rise
# Out:
# array([  2,  14,  15,  27,  28,  40,  41,  53,  66,  79,  92, 104, 105,
#        116, 117, 126, 129, 130, 131, 142, 143, 144])

# %%
a = np.where(np.diff(rise)<10)[0]+1
a
# Out:
# array([ 2,  4,  6, 12, 14, 15, 16, 17, 18, 20, 21])

# %%
start_indices = np.delete(rise, a)
start_indices
# Out:
# array([  2,  14,  27,  40,  53,  66,  79,  92, 104, 116, 142])

# %%
conv = len(tmp_interp)/(x[-1] - x[0])
end_indices = np.round(start_indices + 6*60*conv).astype(dtype=np.int)

# %%
plt.figure(figsize=(20,10))
plt.plot(time, tmp)
plt.plot(x, tmp_interp)
plt.plot(x[rise], tmp_interp[rise], 'x')
plt.plot(x[start_indices], tmp_interp[start_indices], 'o')
plt.plot(x[end_indices], tmp_interp[end_indices], 'o')
plt.plot(x, np.ones_like(x)*0.336)

# %%
tmp_interp[end_indices]
manual_ends = np.array([0.345,0.38971127, 0.33105063, 0.33838043, 0.31485612, 0.31297967, 0.318, 0.32, 0.32341894, 0.34625661, 0.335,0.336  ])

# %%
#heating = tmp_interp[end_indices]-tmp_interp[start_indices] 
heating = manual_ends - manual_starts
heating *= 1000
heating
# Out:
# array([ 42.48635128, 100.3751024 ,  42.05850034,  49.6487302 ,
#         33.15863274,  25.90900161,  22.94831639,  22.74830812,
#         34.09569603,  56.35457118,  33.30476205])

# %%
az_v = np.linspace(2.35, 2.90, 12)
az_v
# Out:
# array([2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 , 2.75, 2.8 , 2.85,
#        2.9 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(az_v, heating, 'o', label='Az center = 194, El = 53')
plt.title('Heating vs Az speed (250mK bottom)')
plt.ylabel('$\Delta$T after 5 minutes [mK]')
plt.xlabel('Az speed (d/s)')
plt.legend()
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-7e6e13e31054> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 plt.plot(az_v, heating, 'o', label='Az center = 194, El = 53')
#       3 plt.title('Heating vs Az speed (250mK bottom)')
#       4 plt.ylabel('$\Delta$T after 5 minutes [mK]')
#       5 plt.xlabel('Az speed (d/s)')
#
# /scratch/yuyang/conda/envs/toast/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# /scratch/yuyang/conda/envs/toast/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /scratch/yuyang/conda/envs/toast/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /scratch/yuyang/conda/envs/toast/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (12,) and (11,)

# %%
import sys
sys.path.insert(0, '../slowdaq')
from load_slowdaq import load_slow
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
slowdir1 = '/data/pb2/ChileData/slowdaq/22300000/20210219/'
slowdir2 = '/data/pb2/ChileData/slowdaq/22300000/20210220/'

# %%
files1 = sorted(glob(slowdir1+'*'))[-10:]
files1
# Out:
# ['/data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_201548_Run22300738_000.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_201553_Run22300738_001.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_201633_Run22300738_002.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_204641_Run22300738_003.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_211729_Run22300738_004.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_214732_Run22300738_005.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_221845_Run22300738_006.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_224847_Run22300738_007.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_231941_Run22300738_008.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_234943_Run22300738_009.log.gz']

# %%
files2 = sorted(glob(slowdir2+'*'))[:9]
files2
# Out:
# ['/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_002016_Run22300738_010.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_005019_Run22300738_011.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_012117_Run22300738_012.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_015125_Run22300738_013.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_022208_Run22300738_014.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_025210_Run22300738_015.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_032238_Run22300738_016.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_035246_Run22300738_017.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_042344_Run22300738_018.log.gz']

# %%
files = np.concatenate([files1,files2])

# %%
data = load_slow(files = files, slowdir=slowdir, sources=['Lakeshore151'])
# Out:
# Loading /data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_201548_Run22300738_000.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_201553_Run22300738_001.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_201633_Run22300738_002.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_204641_Run22300738_003.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_211729_Run22300738_004.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_214732_Run22300738_005.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_221845_Run22300738_006.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_224847_Run22300738_007.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_231941_Run22300738_008.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210219/slowdaq_20210219_234943_Run22300738_009.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_002016_Run22300738_010.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_005019_Run22300738_011.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_012117_Run22300738_012.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_015125_Run22300738_013.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_022208_Run22300738_014.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_025210_Run22300738_015.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_032238_Run22300738_016.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_035246_Run22300738_017.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_042344_Run22300738_018.log.gz
# Existing sources: Lakeshore151
# Loaging slowdata done. It took 24.147155 seconds

# %%
ls = data['Lakeshore151']
time = np.array(ls['time']) - ls['time'][0]
key = 'MODEL370_370A4A_T'
#l = len(ls[key][0])
tmp = np.array(ls[key])[:,12]

# %%
plt.plot(time, tmp)

# %%
#fig = plt.figure(figsize=(20,10))

# for i in range(l):
#     tmp = np.array(ls[key])[:,i]

#     plt.plot(time, tmp, label=i)
s = 300
e = 5700
plt.plot(time[s:e], tmp[s:e])
#plt.plot(x, tmp_interp)
#plt.plot(x[rise], tmp_interp[rise], 'x')

# %%
time = time[s:e]
tmp = tmp[s:e]

x = np.linspace(time[0], time[-1], 150)
tmp_interp = np.interp(x, time, tmp)

# %%
rise = np.where(np.diff(tmp_interp)>1e-3)[0]
rise
# Out:
# array([  3,   5,   6,  25,  26,  27,  28,  29,  46,  47,  49,  50,  52,
#         67,  68,  70,  71,  88,  89,  91,  92, 109, 110, 112, 113, 130,
#        131, 133, 134, 140])

# %%
a = np.where(np.diff(rise)<10)[0]+1
a
# Out:
# array([ 1,  2,  4,  5,  6,  7,  9, 10, 11, 12, 14, 15, 16, 18, 19, 20, 22,
#        23, 24, 26, 27, 28, 29])

# %%
start_indices = np.delete(rise, a)
start_indices
# Out:
# array([  3,  25,  46,  67,  88, 109, 130])

# %%
conv = len(tmp_interp)/(x[-1] - x[0])
end_indices = np.round(start_indices + 25*60*conv).astype(dtype=np.int)

# %%
plt.figure(figsize=(20,10))
plt.plot(time, tmp)
plt.plot(x, tmp_interp)
plt.plot(x[rise], tmp_interp[rise], 'x')
plt.plot(x[start_indices], tmp_interp[start_indices], 'o')
plt.plot(x[end_indices], tmp_interp[end_indices], 'o')

# %%
heating = tmp_interp[end_indices]-tmp_interp[start_indices] 
heating *= 1000
heating
# Out:
# array([19.93697048, 12.69960579, 10.24328885, 15.42602162, 14.87496945,
#        19.5135117 , 17.08332242])

# %%
az_v = np.linspace(1.60, 1.90, 7)
az_v
# Out:
# array([1.6 , 1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(az_v, heating, 'o', label='Az center = 194, El = 53')
plt.title('Heating vs Az speed (250mK bottom)')
plt.ylabel('$\Delta$T after 25 minutes [mK]')
plt.xlabel('Az speed (d/s)')
plt.legend()
plt.grid()

# %%
import sys
sys.path.insert(0, '../slowdaq')
from load_slowdaq import load_slow
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
slowdir = '/data/pb2/ChileData/slowdaq/22300000/20210304/'

# %%
files = sorted(glob(slowdir+'*797*'))
files
# Out:
# ['/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_003859_Run22300797_000.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_003904_Run22300797_001.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_004432_Run22300797_002.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_011437_Run22300797_003.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_012037_Run22300797_004.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_020537_Run22300797_005.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_021136_Run22300797_006.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_025641_Run22300797_007.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_030244_Run22300797_008.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_034749_Run22300797_009.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_035353_Run22300797_010.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_043857_Run22300797_011.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_044505_Run22300797_012.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_053008_Run22300797_013.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_053622_Run22300797_014.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_062125_Run22300797_015.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_062703_Run22300797_016.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_071206_Run22300797_017.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_071759_Run22300797_018.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_080311_Run22300797_019.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_080900_Run22300797_020.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_085402_Run22300797_021.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_090011_Run22300797_022.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_094512_Run22300797_023.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_095131_Run22300797_024.log.gz']

# %%
data = load_slow(files = files, slowdir=slowdir, sources=['Lakeshore151'])
# Out:
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_003859_Run22300797_000.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_003904_Run22300797_001.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_004432_Run22300797_002.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_011437_Run22300797_003.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_012037_Run22300797_004.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_020537_Run22300797_005.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_021136_Run22300797_006.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_025641_Run22300797_007.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_030244_Run22300797_008.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_034749_Run22300797_009.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_035353_Run22300797_010.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_043857_Run22300797_011.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_044505_Run22300797_012.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_053008_Run22300797_013.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_053622_Run22300797_014.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_062125_Run22300797_015.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_062703_Run22300797_016.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_071206_Run22300797_017.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_071759_Run22300797_018.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_080311_Run22300797_019.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_080900_Run22300797_020.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_085402_Run22300797_021.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_090011_Run22300797_022.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_094512_Run22300797_023.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210304/slowdaq_20210304_095131_Run22300797_024.log.gz
# Existing sources: Lakeshore151
# Loaging slowdata done. It took 42.298208 seconds

# %%
ls = data['Lakeshore151']
time = np.array(ls['time']) - ls['time'][0]
key = 'MODEL370_370A4A_T'
#l = len(ls[key][0])
tmp = np.array(ls[key])[:,12]

# %%
plt.plot(time, tmp)

# %%
#fig = plt.figure(figsize=(20,10))

# for i in range(l):
#     tmp = np.array(ls[key])[:,i]

#     plt.plot(time, tmp, label=i)
s = 300
e = 7800
plt.plot(time[s:e], tmp[s:e])
#plt.plot(x, tmp_interp)
#plt.plot(x[rise], tmp_interp[rise], 'x')

# %%
time = time[s:e]
tmp = tmp[s:e]

x = np.linspace(time[0], time[-1], 150)
tmp_interp = np.interp(x, time, tmp)

# %%
rise = np.where(np.diff(tmp_interp)>1e-3)[0]
rise
# Out:
# array([  4,  16,  17,  29,  30,  42,  44,  56,  57,  69,  70,  82,  83,
#         96, 109, 110, 123, 136])

# %%
a = np.where(np.diff(rise)<10)[0]+1
a
# Out:
# array([ 2,  4,  6,  8, 10, 12, 15])

# %%
start_indices = np.delete(rise, a)
start_indices
# Out:
# array([  4,  16,  29,  42,  56,  69,  82,  96, 109, 123, 136])

# %%
conv = len(tmp_interp)/(x[-1] - x[0])
end_indices = np.ceil(start_indices + 5*60*conv).astype(dtype=np.int)

# %%
plt.figure(figsize=(20,10))
plt.plot(time, tmp)
plt.plot(x, tmp_interp)
plt.plot(x[rise], tmp_interp[rise], 'x')
plt.plot(x[start_indices], tmp_interp[start_indices], 'o')
plt.plot(x[end_indices], tmp_interp[end_indices], 'o')
plt.plot(x, np.ones_like(x)*0.29)

# %%
heating = tmp_interp[end_indices]-tmp_interp[start_indices] 
heating *= 1000
heating
# Out:
# array([ 56.39798, 100.37511,  42.0585 ,  49.64873,  26.05422,  24.03255,
#         27.96864,  30.48593,  34.09569,  56.35457,  45.     ,  44.90466])

# %%
az_v = np.linspace(2.35, 2.90, 12)
az_v
# Out:
# array([2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 , 2.75, 2.8 , 2.85,
#        2.9 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(az_v, heating, 'o', label='Az center = 194, El = 53')
plt.title('Heating vs Az speed (250mK bottom)')
plt.ylabel('$\Delta$T after 5 minutes [mK]')
plt.xlabel('Az speed (d/s)')
plt.legend()
plt.grid()

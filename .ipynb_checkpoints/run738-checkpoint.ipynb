# %%
import sys
sys.path.insert(0, '../slowdaq')
from load_slowdaq import load_slow
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
slowdir = '/data/pb2/ChileData/slowdaq/22300000/20210213/'

# %%
files = sorted(glob(slowdir+'*'))[24:50]

# %%
data = load_slow(files = files, slowdir=slowdir, sources=['Lakeshore151'])
# Out:
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_012038_Run22300648_000.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_020544_Run22300648_002.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_020550_Run22300648_003.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_024022_Run22300648_004.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_032528_Run22300648_006.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_032534_Run22300648_007.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_040056_Run22300648_008.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_044602_Run22300648_010.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_044607_Run22300648_011.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_052220_Run22300648_012.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_060727_Run22300648_014.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_060732_Run22300648_015.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_064330_Run22300648_016.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_072831_Run22300648_017.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_072836_Run22300648_018.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_072841_Run22300648_019.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_080535_Run22300648_020.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_085036_Run22300648_021.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_085041_Run22300648_023.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_092835_Run22300648_024.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_101336_Run22300648_025.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_101341_Run22300648_027.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_105235_Run22300648_028.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_113736_Run22300648_029.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_113741_Run22300648_030.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210213/slowdaq_20210213_113747_Run22300648_031.log.gz
# Existing sources: Lakeshore151
# Loaging slowdata done. It took 31.034310 seconds

# %%
ls = data['Lakeshore151']
time = np.array(ls['time']) - ls['time'][0]
key = 'MODEL370_370A4A_T'
#l = len(ls[key][0])
tmp = np.array(ls[key])[:,12]

# %%
plt.plot(time, tmp)

# %%
#fig = plt.figure(figsize=(20,10))

# for i in range(l):
#     tmp = np.array(ls[key])[:,i]

#     plt.plot(time, tmp, label=i)
s = 300
e = 7500
plt.plot(time[s:e], tmp[s:e])
#plt.plot(x, tmp_interp)
#plt.plot(x[rise], tmp_interp[rise], 'x')

# %%
time = time[s:e]
tmp = tmp[s:e]

x = np.linspace(time[0], time[-1], 150)
tmp_interp = np.interp(x, time, tmp)

# %%
rise = np.where(np.diff(tmp_interp)>1e-3)[0]
rise
# Out:
# array([  5,   6,   7,  27,  28,  29,  48,  49,  50,  69,  70,  71,  72,
#         90,  91,  92,  93, 113, 114, 133, 134, 135, 137])

# %%
a = np.where(np.diff(rise)<10)[0]+1
a
# Out:
# array([ 1,  2,  4,  5,  7,  8, 10, 11, 12, 14, 15, 16, 18, 20, 21, 22])

# %%
start_indices = np.delete(rise, a)
start_indices
# Out:
# array([  5,  27,  48,  69,  90, 113, 133])

# %%
conv = len(tmp_interp)/(x[-1] - x[0])
end_indices = np.round(start_indices + 30*60*conv).astype(dtype=np.int)

# %%
plt.figure(figsize=(20,10))
plt.plot(time, tmp)
plt.plot(x, tmp_interp)
plt.plot(x[rise], tmp_interp[rise], 'x')
plt.plot(x[start_indices], tmp_interp[start_indices], 'o')
plt.plot(x[end_indices], tmp_interp[end_indices], 'o')

# %%
heating = tmp_interp[end_indices]-tmp_interp[start_indices] 
heating *= 1000
heating
# Out:
# array([48.62559416, 14.77257427, 11.57079981,  7.5187465 , 13.45143889,
#         5.58121633, 13.54766137])

# %%
sky_v = np.linspace(0.70, 1.0, 7)
sky_v
# Out:
# array([0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])

# %%
az_v = sky_v/np.cos(53*np.pi/180)
az_v
# Out:
# array([1.1631481 , 1.24623011, 1.32931211, 1.41239412, 1.49547613,
#        1.57855813, 1.66164014])

# %%
plt.figure(figsize=(20,10))
plt.plot(az_v, heating, 'o', label='Az center = 194, El = 53')
plt.title('Heating vs Az speed (250mK bottom)')
plt.ylabel('$\Delta$T after 30 minutes [mK]')
plt.xlabel('Az speed (d/s)')
plt.legend()
plt.grid()

# %%
import sys
sys.path.insert(0, '../slowdaq')
from load_slowdaq import load_slow
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
slowdir = '/data/pb2/ChileData/slowdaq/22300000/20210212/'

# %%
files = sorted(glob(slowdir+'*'))[29:-4]

# %%
data = load_slow(files = files, slowdir=slowdir, sources=['Lakeshore151'])
# Out:
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_032729_Run22300646_000.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_041234_Run22300646_002.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_041239_Run22300646_003.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_044558_Run22300646_004.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_053101_Run22300646_005.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_053106_Run22300646_006.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_053111_Run22300646_007.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_060248_Run22300646_008.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_064754_Run22300646_010.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_064759_Run22300646_011.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_072021_Run22300646_012.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_080528_Run22300646_014.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_080533_Run22300646_015.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_083835_Run22300646_016.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_092341_Run22300646_018.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_092346_Run22300646_019.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_095733_Run22300646_020.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_104240_Run22300646_022.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_104245_Run22300646_023.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_111712_Run22300646_024.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_120214_Run22300646_025.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_120219_Run22300646_026.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_120224_Run22300646_027.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_123606_Run22300646_028.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_132112_Run22300646_030.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_132117_Run22300646_031.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_135550_Run22300646_032.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_144056_Run22300646_034.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_144101_Run22300646_035.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_151624_Run22300646_036.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_160130_Run22300646_038.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_160135_Run22300646_039.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210212/slowdaq_20210212_163749_Run22300646_040.log.gz
# Existing sources: Lakeshore151
# Loaging slowdata done. It took 30.844725 seconds

# %%
ls = data['Lakeshore151']
time = np.array(ls['time']) - ls['time'][0]
key = 'MODEL370_370A4A_T'
#l = len(ls[key][0])
tmp = np.array(ls[key])[:,12]

# %%
#fig = plt.figure(figsize=(20,10))

# for i in range(l):
#     tmp = np.array(ls[key])[:,i]

#     plt.plot(time, tmp, label=i)
s = 100
e = 9000
plt.plot(time[s:e], tmp[s:e])
#plt.plot(x, tmp_interp)
#plt.plot(x[rise], tmp_interp[rise], 'x')

# %%
time = time[s:e]
tmp = tmp[s:e]

x = np.linspace(time[0], time[-1], 150)
tmp_interp = np.interp(x, time, tmp)

# %%
rise = np.where(np.diff(tmp_interp)>1e-3)[0]
rise
# Out:
# array([  6,   7,   8,   9,  23,  24,  25,  40,  56,  57,  58,  73,  74,
#         90,  91,  92, 107, 108, 109, 111, 124, 125, 126, 141, 142, 145])

# %%
a = np.where(np.diff(rise)<10)[0]+1
a
# Out:
# array([ 1,  2,  3,  5,  6,  9, 10, 12, 14, 15, 17, 18, 19, 21, 22, 24, 25])

# %%
start_indices = np.delete(rise, a)
start_indices
# Out:
# array([  6,  23,  40,  56,  73,  90, 107, 124, 141])

# %%
conv = len(tmp_interp)/(x[-1] - x[0])
end_indices = np.round(start_indices + 30*60*conv).astype(dtype=np.int)

# %%
plt.figure(figsize=(20,10))
plt.plot(time, tmp)
plt.plot(x, tmp_interp)
plt.plot(x[rise], tmp_interp[rise], 'x')
plt.plot(x[start_indices], tmp_interp[start_indices], 'o')
plt.plot(x[end_indices], tmp_interp[end_indices], 'o')

# %%
heating = tmp_interp[end_indices]-tmp_interp[start_indices] 
heating *= 1000

# %%
sky_v = np.linspace(0.35, 0.75, 9)
az_v = sky_v/np.cos(53*np.pi/180)
az_v
# Out:
# array([0.58157405, 0.66465606, 0.74773806, 0.83082007, 0.91390208,
#        0.99698408, 1.08006609, 1.1631481 , 1.24623011])

# %%
plt.figure(figsize=(20,10))
plt.plot(az_v, heating, 'o', label='Az center = 194, El = 53')
plt.title('Heating vs Az speed (250mK bottom)')
plt.ylabel('$\Delta$T after 30 minutes [mK]')
plt.xlabel('Az speed (d/s)')
plt.legend()
plt.grid()

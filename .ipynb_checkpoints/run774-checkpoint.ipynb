# %%
import sys
sys.path.insert(0, '../slowdaq')
from load_slowdaq import load_slow
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
slowdir = '/data/pb2/ChileData/slowdaq/22300000/20210220/'

# %%
files = sorted(glob(slowdir+'*'))[70:80]
files
# Out:
# ['/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_142353_Run22300742_001.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_142931_Run22300742_002.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_145933_Run22300742_003.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_150526_Run22300742_004.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_160029_Run22300742_005.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_160621_Run22300742_006.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_170125_Run22300742_007.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_170717_Run22300742_008.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_180220_Run22300742_009.log.gz',
#  '/data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_180813_Run22300742_010.log.gz']

# %%
data = load_slow(files = files, slowdir=slowdir, sources=['Lakeshore151'])
# Out:
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_142353_Run22300742_001.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_142931_Run22300742_002.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_145933_Run22300742_003.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_150526_Run22300742_004.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_160029_Run22300742_005.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_160621_Run22300742_006.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_170125_Run22300742_007.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_170717_Run22300742_008.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_180220_Run22300742_009.log.gz
# Loading /data/pb2/ChileData/slowdaq/22300000/20210220/slowdaq_20210220_180813_Run22300742_010.log.gz
# Existing sources: Lakeshore151
# Loaging slowdata done. It took 14.385605 seconds

# %%
ls = data['Lakeshore151']
time = np.array(ls['time']) - ls['time'][0]
key = 'MODEL370_370A4A_T'
#l = len(ls[key][0])
tmp = np.array(ls[key])[:,12]

# %%
plt.plot(time, tmp)

# %%
#fig = plt.figure(figsize=(20,10))

# for i in range(l):
#     tmp = np.array(ls[key])[:,i]

#     plt.plot(time, tmp, label=i)
s = 300
e = 5700
plt.plot(time[s:e], tmp[s:e])
#plt.plot(x, tmp_interp)
#plt.plot(x[rise], tmp_interp[rise], 'x')

# %%
time = time[s:e]
tmp = tmp[s:e]

x = np.linspace(time[0], time[-1], 150)
tmp_interp = np.interp(x, time, tmp)

# %%
rise = np.where(np.diff(tmp_interp)>1e-3)[0]
rise
# Out:
# array([  7,   9,  10,  43,  45,  79,  80, 115])

# %%
a = np.where(np.diff(rise)<10)[0]+1
a
# Out:
# array([1, 2, 4, 6])

# %%
start_indices = np.delete(rise, a)
start_indices
# Out:
# array([  7,  43,  79, 115])

# %%
conv = len(tmp_interp)/(x[-1] - x[0])
end_indices = np.round(start_indices + 5*60*conv).astype(dtype=np.int)

# %%
plt.figure(figsize=(20,10))
plt.plot(time, tmp)
plt.plot(x, tmp_interp)
plt.plot(x[rise], tmp_interp[rise], 'x')
plt.plot(x[start_indices], tmp_interp[start_indices], 'o')
plt.plot(x[end_indices], tmp_interp[end_indices], 'o')

# %%
heating = tmp_interp[end_indices]-tmp_interp[start_indices] 
heating *= 1000
heating
# Out:
# array([134.25494386, 134.41573867, 117.67547248,  97.68316909])

# %%
az_v = np.linspace(2.15, 2.30, 4)
az_v
# Out:
# array([2.15, 2.2 , 2.25, 2.3 ])

# %%
plt.figure(figsize=(20,10))
plt.plot(az_v, heating, 'o', label='Az center = 194, El = 53')
plt.title('Heating vs Az speed (250mK bottom)')
plt.ylabel('$\Delta$T after 5 minutes [mK]')
plt.xlabel('Az speed (d/s)')
plt.legend()
plt.grid()
